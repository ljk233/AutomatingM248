# %% [markdown]
# # A05. From Samples to Models for Discrete Data
#
# -----
#
#     2020-10-08

# %% [markdown]
# Visualising the *settling down* phenomenon.
#
# > *In a long sequence of repetitions of a study or experiment, bar charts and histograms of samples tend to settle down towards probability distributions*

# %%
from random import randrange
import seaborn as sns
import M248.probability as p

# %% [markdown]
# ## Simulations
#
# -----

# %%
# rolling 10 times
roll30 = p.simulateDieRolls(10)

# %%
# rolling 100 times
roll100 = p.simulateDieRolls(100)

# %%
# rolling 1000 times
roll1000 = p.simulateDieRolls(1000)

# %%
# rolling 10000 times
roll10000 = p.simulateDieRolls(10000)
