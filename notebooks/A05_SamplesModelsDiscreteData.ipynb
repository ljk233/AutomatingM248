# %% [markdown]
# # A05. From Samples to Models for Discrete Data
#
# -----
#
# Visualising the *settling down* phenomenon.
#
# > *In a long sequence of repetitions of a study or experiment, bar charts and histograms of samples tend to settle down towards probability distributions*

# %% [markdown]
# `automateM248` has two support functions defined: `rollDie()` and `simulateDieRolls()`
#
# `simulateDieRolls(arg int)`
# : Invokes `rollDie(arg int)`, which returns a list of `arg` simulations of a dice roll.
# The p.d.f. is then plotted by `seaborn`.

# %%
from random import randrange
import seaborn as sns
import automateM248 as m248

# %% [markdown]
# ## Simulations
#
# -----

# %%
# rolling 10 times
roll30 = m248.simulateDieRolls(10)

# %%
# rolling 100 times
roll100 = m248.simulateDieRolls(100)

# %%
# rolling 1000 times
roll1000 = m248.simulateDieRolls(1000)

# %%
# rolling 10000 times
roll10000 = m248.simulateDieRolls(10000)
