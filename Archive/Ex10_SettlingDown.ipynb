# %% [markdown]
# # Settling Down in Python
#
# Date: 2020-11-02
#
# Visualising the *settling down* phenomenon using Python.
#
# > *In a long sequence of repetitions of a study or experiment, bar charts and histograms of samples tend to settle down towards probability distributions*
#
# We will use two distributions to visualise this:
#
# - Poisson distribution ($\mu = 10$)
# - Exponential distribution ($\lambda = 2$)
#
# The plots show random samples of increasing sizes with the probability function superimposed.
# It is evident that as $N$ increases, the plot of the sample does move to mirror the probability function.
#
# ## References
#
# This notebook makes use of a modified function from the **scipy** website.
# See the below references for the original implementations.
#
# - [scipy.stats.poisson](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.poisson.html)
# - [scipy.stats.expon](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.expon.html)

# %%
from M248.support import samplePoisson, sampleExponential

# %% [markdown]
# ## Poisson distribution

# %% [markdown]
# ### Size=30

# %%
samplePoisson(N=30)

# %% [markdown]
# ### Size=300

# %%
samplePoisson(N=300)

# %% [markdown]
# ### Size=1000

# %%
samplePoisson(N=1000)

# %% [markdown]
# ### Size=10000

# %%
samplePoisson(N=10000)

# %% [markdown]
# ### Size=100000

# %%
samplePoisson(N=100000)

# %% [markdown]
# ## Exponential distribution

# %% [markdown]
# ### Size=30

# %%
sampleExponential(N=30)

# %% [markdown]
# ### Size=300

# %%
sampleExponential(N=300)

# %% [markdown]
# ### Size=1000

# %%
sampleExponential(N=1000)

# %% [markdown]
# ### Size=10000

# %%
sampleExponential(N=10000)

# %% [markdown]
# ### Size=100000

# %%
sampleExponential(N=100000)
