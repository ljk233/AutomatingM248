# %% [markdown]
# # Visualisation: Settling down phenomenon
#
# **date**
# : 2021-04-09
#
# **data**
# : -
#
# **ref**
# : Computer book A, Activity 24
#
# **desc**
# : Illustrate the *settling down* phenomenon using the **Poisson(5)** and standard normal distributions.
# We should see that, as the sample size increases, the plots becomes more like the probability functions of the distributions.

# %%
from scripts.settling_down import SettlingDown
from scipy.stats import poisson, expon

# %% [markdown]
# # Example 1: Poisson(3)

# %% [markdown]
# Declare and construct an object of type `SettlingDown`, passing `poisson(3)` over as an actual argument for `a_dist`.

# %%
# declare and constrcut new object
poiss: SettlingDown = SettlingDown(a_dist=poisson(3),is_discrete=True)

# %% [markdown]
# Let us first plot the probability mass fuction of **Poisson(3)**

# %%
poiss.plot_prob_function()

# %% [markdown]
# Let us now compare this to random samples from the same distribution with increasing size.

# %%
poiss.plot_samples()

# %% [markdown]
# ## Example 2: Normal(0, 1)

# %% [markdown]
# Declare and construct an object of type `SettlingDown`, passing `norm()` over as an actual argument for `a_dist`.

# %%
# declare and constrcut new object
normal: SettlingDown = SettlingDown(a_dist=expon(), is_discrete=False)

# %% [markdown]
# Let us first plot the probability density fuction of the standard normal distribution.

# %%
normal.plot_prob_function()

# %% [markdown]
# Let us now compare this to random samples from the same distribution with increasing size.

# %%
normal.plot_samples()
