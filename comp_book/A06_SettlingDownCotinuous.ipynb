# %% [markdown]
# # A6. Settling Down Phenomenon in Continuous Data
#
# Date: 2020-11-02
#
# ## Background
#
# Visualising the *settling down* phenomenon in continuous data using Python.
#
# > *In a long sequence of repetitions of a study or experiment, bar charts and histograms of samples tend to settle down towards probability distributions*
#
# ## About
#
# We will use $M(2)$ to visualise this phenomenon.
# The plots show random samples of increasing sizes with the probability function superimposed.
# It is evident that as the sample size increases, the plot of the sample does move to mirror the probability function.
#
# ## References
#
# This notebook makes use of a modified function from the **scipy** website.
# See the below references for the original implementations.
#
# - [scipy.stats.expon](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.expon.html)

# %%
from util.settlingdown import sample_exponential

# %% [markdown]
# ## Settling down: Exponential distribution

# %%
sample_exponential(sample_size=30)

# %%
sample_exponential(sample_size=300)

# %%
sample_exponential(sample_size=1000)

# %%
sample_exponential(sample_size=10000)
