# %% [markdown]
# # A05. From Samples to Models for Discrete Data
#
# -----
#
#     2020-10-08
#
# Notebook was refactored to use `scipy.stats.randint`

# %% [markdown]
# Visualising the *settling down* phenomenon.
#
# > *In a long sequence of repetitions of a study or experiment, bar charts and histograms of samples tend to settle down towards probability distributions*

# %% [markdown]
# ## Plotting p(x)

# %%
import scipy.stats as stats
import seaborn as sns
import numpy as np

# %%
# generated array of x 1:6
X = np.arange(1, 7)

# declate randint
rv = stats.randint(1, 7)
p = list()

# for each x in X
for i in X:
    # calculate p(x), append to list
    p.append(rv.pmf(i))

# plot p(x)
ax1 = sns.barplot(x=X, y=p, palette="Blues_d")
ax1.set(xlabel='x', ylabel='p(x)', title='Poisson(8)')
# Out:
# [Text(0.5, 0, 'x'), Text(0, 0.5, 'p(x)'), Text(0.5, 1.0, 'Poisson(8)')]

# %% [markdown]
# ## Simulations
#
# -----

# %%
# rolling 10 times
r = stats.randint.rvs(low=1, high=7, size=10)
ax2 = sns.countplot(x=r, palette="Blues_d")
ax2.set(xlabel='x', ylabel='Frequency')
# Out:
# [Text(0.5, 0, 'x'), Text(0, 0.5, 'Frequency')]

# %%
# rolling 100 times
r = stats.randint.rvs(low=1, high=7, size=100)
ax2 = sns.countplot(x=r, palette="Blues_d")
ax2.set(xlabel='x', ylabel='Frequency')
# Out:
# [Text(0.5, 0, 'x'), Text(0, 0.5, 'Frequency')]

# %%
# rolling 1000 times
r = stats.randint.rvs(low=1, high=7, size=1000)
ax2 = sns.countplot(x=r, palette="Blues_d")
ax2.set(xlabel='x', ylabel='Frequency')
# Out:
# [Text(0.5, 0, 'x'), Text(0, 0.5, 'Frequency')]

# %%
# rolling 10000 times
r = stats.randint.rvs(low=1, high=7, size=10000)
ax2 = sns.countplot(x=r, palette="Blues_d")
ax2.set(xlabel='x', ylabel='Frequency')
# Out:
# [Text(0.5, 0, 'x'), Text(0, 0.5, 'Frequency')]

# %%
# rolling 100000 times
r = stats.randint.rvs(low=1, high=7, size=100000)
ax2 = sns.countplot(x=r, palette="Blues_d")
ax2.set(xlabel='x', ylabel='Frequency')
# Out:
# [Text(0.5, 0, 'x'), Text(0, 0.5, 'Frequency')]
